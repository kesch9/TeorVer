# %% [markdown]
# ### Задание 1
# Вероятность того, что стрелок попадет в мишень, выстрелив один раз, равна 0.8. Стрелок выстрелил 100 раз. Найдите вероятность того, что стрелок попадет в цель ровно 85 раз.

# %%
import math
### Теорема Пуассона
def Puasson(p,n,m):
    l = n * p
    P = l ** m/ math.factorial(m) * math.e**(-l)
    print ("P = ", P)
    return P
### Теорема Бернулли
def Bernulli(n,k,p,q):
    C = math.factorial(n) / (math.factorial(k) * math.factorial(n-k))
    P = C * p**k * q**(n-k)
    print ('C = ', C)
    print ('P = ', P)
    return P

# %%
### Теорема Пуассона
p = 0.8
n = 100
m = 85
Puasson(p,n,m)
# Out:
# P =  0.037092614343691946
# 0.037092614343691946

# %%
### Формула Бернулли
n = 100
k = 85
p = 0.8
q = 0.2
Bernulli(n,k,p,q)
# Out:
# C =  2.5333847134998864e+17
# P =  0.048061793700746556
# 0.048061793700746556

# %% [markdown]
# ### Задание 2
# Вероятность того, что лампочка перегорит в течение первого дня эксплуатации, равна 0.0004. В жилом комплексе после ремонта в один день включили 5000 новых лампочек. Какова вероятность, что ни одна из них не перегорит в первый день? Какова вероятность, что перегорят ровно две?

# %%
### Теорема Пуассона
p = 0.0004
n = 5000
l = n * p
m = 0
print("Вероятность что ни одна не перегорит лампочка = ", Puasson(p,n,m))
m = 2
print("Вероятность что две лампочки перегорят = ", Puasson(p,n,m))
# Out:
# P =  0.1353352832366127
# Вероятность что ни одна не перегорит лампочка =  0.1353352832366127
# P =  0.2706705664732254
# Вероятность что две лампочки перегорят =  0.2706705664732254

# %% [markdown]
# ### Задание 3
# Монету подбросили 144 раза. Какова вероятность, что орел выпадет ровно 70 раз?

# %%
### Формула Бернулли
n = 144
k = 70
p = q = 0.5
Bernulli(n,k,p,q)
# Out:
# C =  1.4007495090837087e+42
# P =  0.06281178035144776
# 0.06281178035144776

# %% [markdown]
# ### Задание 4
# В первом ящике находится 10 мячей, из которых 7 - белые. Во втором ящике - 11 мячей, из которых 9 белых. Из каждого ящика вытаскивают случайным образом по два мяча. Какова вероятность того, что все мячи белые? Какова вероятность того, что ровно два мяча белые? Какова вероятность того, что хотя бы один мяч белый?

# %%
print("Какова вероятность того, что все мячи белые?") 
n = 2
k = 2
print("Вероятность первого ящика")
p1 = 0.7
q1 = 0.3
P1 = Bernulli(n,k,p1,q1)
print("Вероятность второго ящика")
p2 = 9/11
q2 = 2/11
P2 = Bernulli(n,k,p2,q2)
Pall = (P1 + P2)/2
print("Вероятность того, что все мячи белые = ", Pall)
print("-------------------------------------------------")

print("Какова вероятность того, что ровно два мяча белые") 
print("Посчитаем все вероятности для различных сочетаний и сложим все вероятности")
Pall = 0
print("2 из первого ящика и 0 из второго")
Pall += (Bernulli(n,2,p1,q1) + Bernulli(n,0,p2,q2))/2
print("0 из первого ящика и 2 из второго")
Pall += (Bernulli(n,0,p1,q1) + Bernulli(n,2,p2,q2))/2
print("1 из первого ящика и 1 из второго")
Pall += (Bernulli(n,1,p1,q1) + Bernulli(n,1,p2,q2))/2
print("Вероятность того, что ровно два мяча белые = ", Pall/3)

print("-------------------------------------------------")
print("Какова вероятность того, что хотя бы один мяч белый") 
print("0 из первого ящика и 0 из второго") 
Pall = (Bernulli(n,0,p1,q1) + Bernulli(n,0,p2,q2))/2
print("Вероятность того, что  хотя бы один мяч белый = ", 1-Pall)
# Out:
# Какова вероятность того, что все мячи белые?
# Вероятность первого ящика
# C =  1.0
# P =  0.48999999999999994
# Вероятность второго ящика
# C =  1.0
# P =  0.6694214876033059
# Вероятность того, что все мячи белые =  0.5797107438016529
# -------------------------------------------------
# Какова вероятность того, что ровно два мяча белые
# Посчитаем все вероятности для различных сочетаний и сложим все вероятности
# 2 из первого ящика и 0 из второго
# C =  1.0
# P =  0.48999999999999994
# C =  1.0
# P =  0.03305785123966942
# 0 из первого ящика и 2 из второго
# C =  1.0
# P =  0.09
# C =  1.0
# P =  0.6694214876033059
# 1 из первого ящика и 1 из второго
# C =  2.0
# P =  0.42
# C =  2.0
# P =  0.2975206611570248
# Вероятность того, что ровно два мяча белые =  0.3333333333333333
# -------------------------------------------------
# Какова вероятность того, что хотя бы один мяч белый
# 0 из первого ящика и 0 из второго
# C =  1.0
# P =  0.09
# C =  1.0
# P =  0.03305785123966942
# ...
